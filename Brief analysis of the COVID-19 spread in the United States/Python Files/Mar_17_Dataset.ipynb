# %%
# Load libraries
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# read data into a DataFrame
data = pd.read_csv('C:/Users/Maverick/Desktop/Machine Learning/Project/Datasetu.csv', index_col=0)
data.head()
# Out:
#            State  Cases_Feb_29  Cases_Mar_17  Cases_Mar_31  Cases_Apr_19  \
# rank
# 24       Alabama             0            39           999          4837
# 49        Alaska             0             6           133           319
# 14       Arizona             1            20          1298          4929
# 33      Arkansas             0            22           564          1777
# 1     California            28           732          8582         30852
#
#       Population   Density    White_Race  Black_Or_African_Race    Other_Race  \
# rank
# 24       4908621   96.9221  3.347189e+06           1.304711e+06  7.068414e+04
# 49        734002    1.2863  4.759269e+05           2.400187e+04  1.093663e+04
# 14       7378494   64.9550  5.697673e+06           3.239159e+05  5.009997e+05
# 33       3038999   58.4030  2.340029e+06           4.683097e+05  8.022957e+04
# 1       39937489  256.3727  2.400243e+07           2.312381e+06  5.523355e+06
#
# ...

# %% [markdown]
# ### Single Linear Regression
# To find the attributes that have relation to the number of cases.
# The coefficient and pvalue is found out.

# %%
# this is the standard import if you're using "formula notation" (similar to R)
import statsmodels.formula.api as smf

# create a fitted model in one line
Pop_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Population', data=data).fit()

# print the coefficients
print(Pop_Cases_lm.params)
print(Pop_Cases_lm.pvalues)
# Out:
# Intercept    -1.039554
# Population    0.000018
# dtype: float64
# Intercept     0.978305
# Population    0.000026
# dtype: float64

# %%
# create a fitted model in one line
Density_Cases_lm = smf.ols(formula='Cases_Per_Sq_Mile_Mar_17 ~ Density', data=data).fit()

# print the coefficients
print(Density_Cases_lm.params)
print(Density_Cases_lm.pvalues)
# Out:
# Intercept   -63.876901
# Density       0.452093
# dtype: float64
# Intercept    2.851958e-02
# Density      4.877774e-31
# dtype: float64

# %%
# create a fitted model in one line
White_Race_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ White_Race', data=data).fit()

# print the coefficients
print(White_Race_Cases_lm.params)
print(White_Race_Cases_lm.pvalues)
# Out:
# Intercept    -0.434521
# White_Race    0.000025
# dtype: float64
# Intercept     0.991551
# White_Race    0.000148
# dtype: float64

# %%
# create a fitted model in one line
Black_Or_African_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Black_Or_African_Race', data=data).fit()

# print the coefficients
print(Black_Or_African_Cases_lm.params)
print(Black_Or_African_Cases_lm.pvalues)
# Out:
# Intercept                33.000156
# Black_Or_African_Race     0.000100
# dtype: float64
# Intercept                0.419872
# Black_Or_African_Race    0.002541
# dtype: float64

# %%
# create a fitted model in one line
Other_Race_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Other_Race', data=data).fit()

# print the coefficients
print(Other_Race_Cases_lm.params)
print(Other_Race_Cases_lm.pvalues)
# Out:
# Intercept     61.374535
# Other_Race     0.000171
# dtype: float64
# Intercept     0.045985
# Other_Race    0.000009
# dtype: float64

# %%
# create a fitted model in one line
Asian_Race_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Asian_Race', data=data).fit()

# print the coefficients
print(Asian_Race_Cases_lm.params)
print(Asian_Race_Cases_lm.pvalues)
# Out:
# Intercept     54.840395
# Asian_Race     0.000172
# dtype: float64
# Intercept     0.073187
# Asian_Race    0.000004
# dtype: float64

# %%
# create a fitted model in one line
Two_Or_More_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Two_Or_More_Race', data=data).fit()

# print the coefficients
print(Two_Or_More_Cases_lm.params)
print(Two_Or_More_Cases_lm.pvalues)
# Out:
# Intercept           14.817430
# Two_Or_More_Race     0.000481
# dtype: float64
# Intercept           0.667212
# Two_Or_More_Race    0.000007
# dtype: float64

# %%
# create a fitted model in one line
Native_American_Race_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Native_American_Race', data=data).fit()

# print the coefficients
print(Native_American_Race_Cases_lm.params)
print(Native_American_Race_Cases_lm.pvalues)
# Out:
# Intercept               73.525801
# Native_American_Race     0.000772
# dtype: float64
# Intercept               0.079581
# Native_American_Race    0.087616
# dtype: float64

# %%
# create a fitted model in one line
Native_Hawaiian_Race_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Native_Hawaiian_Race', data=data).fit()

# print the coefficients
print(Native_Hawaiian_Race_Cases_lm.params)
print(Native_Hawaiian_Race_Cases_lm.pvalues)
# Out:
# Intercept               82.724825
# Native_Hawaiian_Race     0.002821
# dtype: float64
# Intercept               0.020793
# Native_Hawaiian_Race    0.013604
# dtype: float64

# %%
# create a fitted model in one line
Employed_People_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Employed_People', data=data).fit()

# print the coefficients
print(Employed_People_Cases_lm.params)
print(Employed_People_Cases_lm.pvalues)
# Out:
# Intercept         -4.505863
# Employed_People    0.000039
# dtype: float64
# Intercept          0.906578
# Employed_People    0.000021
# dtype: float64

# %%
# create a fitted model in one line
UnEmployed_People_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ UnEmployed_People', data=data).fit()

# print the coefficients
print(UnEmployed_People_Cases_lm.params)
print(UnEmployed_People_Cases_lm.pvalues)
# Out:
# Intercept            2.278279
# UnEmployed_People    0.000033
# dtype: float64
# Intercept            0.952296
# UnEmployed_People    0.000033
# dtype: float64

# %%
# create a fitted model in one line
Mean_Temp_Mar_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Mean_Temp_Mar', data=data).fit()

# print the coefficients
print(Mean_Temp_Mar_Cases_lm.params)
print(Mean_Temp_Mar_Cases_lm.pvalues)
# Out:
# Intercept        25.361524
# Mean_Temp_Mar     2.015136
# dtype: float64
# Intercept        0.871371
# Mean_Temp_Mar    0.555598
# dtype: float64

# %%
# create a fitted model in one line
Median_Age_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Median_Age', data=data).fit()

# print the coefficients
print(Median_Age_Cases_lm.params)
print(Median_Age_Cases_lm.pvalues)
# Out:
# Intercept     212.179455
# Median_Age     -2.526102
# dtype: float64
# Intercept     0.697623
# Median_Age    0.859246
# dtype: float64

# %%
# create a fitted model in one line
Air_Pollution_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Air_Pollution', data=data).fit()

# print the coefficients
print(Air_Pollution_Cases_lm.params)
print(Air_Pollution_Cases_lm.pvalues)
# Out:
# Intercept        152.993232
# Air_Pollution     -4.936995
# dtype: float64
# Intercept        0.421817
# Air_Pollution    0.841229
# dtype: float64

# %%
# create a fitted model in one line
Asthma_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Asthma', data=data).fit()

# print the coefficients
print(Asthma_Cases_lm.params)
print(Asthma_Cases_lm.pvalues)

# create a fitted model in one line
Diabetes_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Diabetes', data=data).fit()

# print the coefficients
print(Diabetes_Cases_lm.params)
print(Diabetes_Cases_lm.pvalues)

# create a fitted model in one line
Teeth_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Six_Plus_Teeth_Extractions', data=data).fit()

# print the coefficients
print(Teeth_Cases_lm.params)
print(Teeth_Cases_lm.pvalues)

# create a fitted model in one line
hbp_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ High_Blood_Pressure', data=data).fit()

# print the coefficients
print(hbp_Cases_lm.params)
print(hbp_Cases_lm.pvalues)

# create a fitted model in one line
multiple_chronic_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Multiple_Chronic_Conditions_Seniors', data=data).fit()

# print the coefficients
print(multiple_chronic_Cases_lm.params)
print(multiple_chronic_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Disease_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Heart_Disease', data=data).fit()

# print the coefficients
print(Heart_Disease_Cases_lm.params)
print(Heart_Disease_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Attack_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Heart_Attack', data=data).fit()

# print the coefficients
print(Heart_Attack_Cases_lm.params)
print(Heart_Attack_Cases_lm.pvalues)

# create a fitted model in one line
Stroke_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Stroke', data=data).fit()

# print the coefficients
print(Stroke_Cases_lm.params)
print(Stroke_Cases_lm.pvalues)

# create a fitted model in one line
High_Cholesterol_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ High_Cholesterol', data=data).fit()

# print the coefficients
print(High_Cholesterol_Cases_lm.params)
print(High_Cholesterol_Cases_lm.pvalues)
# Out:
# Intercept    0.985534
# Asthma       0.000221
# dtype: float64
# Intercept    0.979870
# Asthma       0.000054
# dtype: float64
# Intercept    10.077346
# Diabetes      0.000143
# dtype: float64
# Intercept    0.798817
# Diabetes     0.000168
# dtype: float64
# Intercept                    -1.955529
# Six_Plus_Teeth_Extractions    0.000099
# dtype: float64
# Intercept                     0.963624
# Six_Plus_Teeth_Extractions    0.000320
# dtype: float64
# Intercept              2.485402
# High_Blood_Pressure    0.000054
# dtype: float64
# Intercept              0.950976
# High_Blood_Pressure    0.000139
# dtype: float64
# Intercept                              6.561305
# Multiple_Chronic_Conditions_Seniors    0.000045
# dtype: float64
# Intercept                              0.863581
# Multiple_Chronic_Conditions_Seniors    0.000053
# dtype: float64
# Intercept        3.677487
# Heart_Disease    0.000401
# dtype: float64
# Intercept        0.930735
# Heart_Disease    0.000398
# ...

# %% [markdown]
# ### Multiple Linear Regression

# %%
# create a fitted model with best features identified based on their pvalues
mul_pvalues_best_attributes_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Native_Hawaiian_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()

# print the coefficients
mul_pvalues_best_attributes_Cases_lm.params
mul_pvalues_best_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Mar_17   R-squared:                       0.646
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     3.542
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           0.000908
# Time:                        00:28:57   Log-Likelihood:                -325.34
# No. Observations:                  51   AIC:                             686.7
# Df Residuals:                      33   BIC:                             721.4
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with all features
mul_All_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Native_American_Race + Native_Hawaiian_Race + Employed_People + Mean_Temp_Feb + Median_Age + Air_Pollution + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()

# print the coefficients
mul_All_Cases_lm.params
mul_All_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Mar_17   R-squared:                       0.678
# Model:                            OLS   Adj. R-squared:                  0.446
# Method:                 Least Squares   F-statistic:                     2.914
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):            0.00405
# Time:                        00:31:08   Log-Likelihood:                -322.88
# No. Observations:                  51   AIC:                             689.8
# Df Residuals:                      29   BIC:                             732.3
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with features identified to have best rsquared values - based on mean
mul_mean_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Population + White_Race + Other_Race + Asian_Race + Two_Or_More_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + High_Cholesterol', data=data).fit()

#Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Native_Hawaiian_Race + Employed_People + Native_American_Race + Mean_Temp_Mar
# print the coefficients
mul_mean_best_rsquared_attributes_Cases_lm.params
mul_mean_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Mar_17   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.481
# Method:                 Least Squares   F-statistic:                     4.566
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           0.000133
# Time:                        00:33:55   Log-Likelihood:                -327.41
# No. Observations:                  51   AIC:                             682.8
# Df Residuals:                      37   BIC:                             709.9
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with features identified to have best rsquared values - based on median
mul_median_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_Mar_17 ~ Population + White_Race + Other_Race + Asian_Race + Two_Or_More_Race + Employed_People + Asthma + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + High_Cholesterol', data=data).fit()

#Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Native_Hawaiian_Race + Employed_People + Native_American_Race + Mean_Temp_Mar
# print the coefficients
mul_median_best_rsquared_attributes_Cases_lm.params
mul_median_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Mar_17   R-squared:                       0.568
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     5.256
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           6.61e-05
# Time:                        00:34:45   Log-Likelihood:                -330.42
# No. Observations:                  51   AIC:                             682.8
# Df Residuals:                      40   BIC:                             704.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...
