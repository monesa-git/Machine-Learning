# %%
# Load libraries
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# read data into a DataFrame
data = pd.read_csv('C:/Users/Maverick/Desktop/Machine Learning/Project/Datasetu.csv', index_col=0)
data.head()
# Out:
#            State  Cases_Feb_29  Cases_Mar_17  Cases_Mar_31  Cases_Apr_19  \
# rank
# 24       Alabama             0            39           999          4837
# 49        Alaska             0             6           133           319
# 14       Arizona             1            20          1298          4929
# 33      Arkansas             0            22           564          1777
# 1     California            28           732          8582         30852
#
#       Population   Density    White_Race  Black_Or_African_Race    Other_Race  \
# rank
# 24       4908621   96.9221  3.347189e+06           1.304711e+06  7.068414e+04
# 49        734002    1.2863  4.759269e+05           2.400187e+04  1.093663e+04
# 14       7378494   64.9550  5.697673e+06           3.239159e+05  5.009997e+05
# 33       3038999   58.4030  2.340029e+06           4.683097e+05  8.022957e+04
# 1       39937489  256.3727  2.400243e+07           2.312381e+06  5.523355e+06
#
#       ...  Air_Pollution       Asthma     Diabetes  \
# rank  ...
# 24    ...            7.4   535039.689   711750.045
# 49    ...            8.4    35966.098    64592.176
# 14    ...            9.7   656685.966   796877.352
# 33    ...            7.1   197534.935   422420.861
# 1     ...           11.9  2955374.190  4153498.860
#
#       Six_Plus_Teeth_Extractions  High_Blood_Pressure  \
# rank
# 24                   1359688.020         2.056712e+06
# 49                    130652.356         2.334126e+05
# 14                   1283857.960         2.265198e+06
# 33                    847880.721         1.255107e+06
# 1                    4832436.170         1.134225e+07
#
#       Multiple_Chronic_Conditions_Seniors  Heart_Disease  Heart_Attack  \
# rank
# 24                           2.095981e+06     299425.881    299425.881
# 49                           1.658845e+05      22754.062     24956.068
# 14                           2.405389e+06     317275.242    339410.724
# 33                           1.109235e+06     194495.936    203612.933
# 1                            1.381837e+07    1277999.650   1198124.670
#
#            Stroke  High_Cholesterol
# rank
# 24     255248.292      1.826007e+06
# 49      19818.054      2.290086e+05
# 14     250868.796      2.464417e+06
# 33     139793.954      1.118352e+06
# 1     1038374.710      1.230075e+07
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Single Linear Regression
# To find the attributes that have relation to the number of cases.
# The coefficient and pvalue is found out.

# %%
# this is the standard import if you're using "formula notation" (similar to R)
import statsmodels.formula.api as smf

# create a fitted model in one line
Pop_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Population', data=data).fit()

# print the coefficients
print(Pop_Cases_lm.params)
print(Pop_Cases_lm.pvalues)
# Out:
# Intercept     1425.255905
# Population       0.002049
# dtype: float64
# Intercept     0.819347
# Population    0.002119
# dtype: float64

# %%
# create a fitted model in one line
Density_Cases_lm = smf.ols(formula='Cases_Per_Sq_Mile_Apr_19 ~ Density', data=data).fit()

# print the coefficients
print(Density_Cases_lm.params)
print(Density_Cases_lm.pvalues)
# Out:
# Intercept   -3368.254758
# Density        40.782411
# dtype: float64
# Intercept    4.571033e-01
# Density      2.620181e-20
# dtype: float64

# %%
# create a fitted model in one line
White_Race_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ White_Race', data=data).fit()

# print the coefficients
print(White_Race_Cases_lm.params)
print(White_Race_Cases_lm.pvalues)
# Out:
# Intercept     1160.848422
# White_Race       0.002871
# dtype: float64
# Intercept     0.859459
# White_Race    0.004077
# dtype: float64

# %%
# create a fitted model in one line
Black_Or_African_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Black_Or_African_Race', data=data).fit()

# print the coefficients
print(Black_Or_African_Cases_lm.params)
print(Black_Or_African_Cases_lm.pvalues)
# Out:
# Intercept                574.640264
# Black_Or_African_Race      0.017219
# dtype: float64
# Intercept                0.922623
# Black_Or_African_Race    0.000453
# dtype: float64

# %%
# create a fitted model in one line
Other_Race_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Other_Race', data=data).fit()

# print the coefficients
print(Other_Race_Cases_lm.params)
print(Other_Race_Cases_lm.pvalues)
# Out:
# Intercept     9733.138039
# Other_Race       0.015774
# dtype: float64
# Intercept     0.064711
# Other_Race    0.010253
# dtype: float64

# %%
# create a fitted model in one line
Asian_Race_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Asian_Race', data=data).fit()

# print the coefficients
print(Asian_Race_Cases_lm.params)
print(Asian_Race_Cases_lm.pvalues)
# Out:
# Intercept     9361.626953
# Asian_Race       0.015253
# dtype: float64
# Intercept     0.079536
# Asian_Race    0.011673
# dtype: float64

# %%
# create a fitted model in one line
Two_Or_More_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Two_Or_More_Race', data=data).fit()

# print the coefficients
print(Two_Or_More_Cases_lm.params)
print(Two_Or_More_Cases_lm.pvalues)
# Out:
# Intercept           6364.711692
# Two_Or_More_Race       0.039968
# dtype: float64
# Intercept           0.292901
# Two_Or_More_Race    0.020547
# dtype: float64

# %%
# create a fitted model in one line
Native_American_Race_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Native_American_Race', data=data).fit()

# print the coefficients
print(Native_American_Race_Cases_lm.params)
print(Native_American_Race_Cases_lm.pvalues)
# Out:
# Intercept               13339.350083
# Native_American_Race        0.025657
# dtype: float64
# Intercept               0.040435
# Native_American_Race    0.709009
# dtype: float64

# %%
# create a fitted model in one line
Native_Hawaiian_Race_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Native_Hawaiian_Race', data=data).fit()

# print the coefficients
print(Native_Hawaiian_Race_Cases_lm.params)
print(Native_Hawaiian_Race_Cases_lm.pvalues)
# Out:
# Intercept               14438.490197
# Native_Hawaiian_Race        0.025633
# dtype: float64
# Intercept               0.011910
# Native_Hawaiian_Race    0.884744
# dtype: float64

# %%
# create a fitted model in one line
Employed_People_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Employed_People', data=data).fit()

# print the coefficients
print(Employed_People_Cases_lm.params)
print(Employed_People_Cases_lm.pvalues)
# Out:
# Intercept          970.190474
# Employed_People      0.004469
# dtype: float64
# Intercept          0.877118
# Employed_People    0.001802
# dtype: float64

# %%
# create a fitted model in one line
UnEmployed_People_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ UnEmployed_People', data=data).fit()

# print the coefficients
print(UnEmployed_People_Cases_lm.params)
print(UnEmployed_People_Cases_lm.pvalues)
# Out:
# Intercept            1853.584587
# UnEmployed_People       0.003772
# dtype: float64
# Intercept            0.765311
# UnEmployed_People    0.002475
# dtype: float64

# %%
# create a fitted model in one line
Mean_Temp_Mar_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Mean_Temp_Mar', data=data).fit()

# print the coefficients
print(Mean_Temp_Mar_Cases_lm.params)
print(Mean_Temp_Mar_Cases_lm.pvalues)
# Out:
# Intercept        13657.959525
# Mean_Temp_Mar       24.101189
# dtype: float64
# Intercept        0.562888
# Mean_Temp_Mar    0.962569
# dtype: float64

# %%
# create a fitted model in one line
Median_Age_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Median_Age', data=data).fit()

# print the coefficients
print(Median_Age_Cases_lm.params)
print(Median_Age_Cases_lm.pvalues)
# Out:
# Intercept    -25839.742975
# Median_Age     1061.185525
# dtype: float64
# Intercept     0.751735
# Median_Age    0.618914
# dtype: float64

# %%
# create a fitted model in one line
Air_Pollution_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Air_Pollution', data=data).fit()

# print the coefficients
print(Air_Pollution_Cases_lm.params)
print(Air_Pollution_Cases_lm.pvalues)
# Out:
# Intercept        44297.857658
# Air_Pollution    -3901.655643
# dtype: float64
# Intercept        0.120106
# Air_Pollution    0.288345
# dtype: float64

# %%
# create a fitted model in one line
Asthma_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Asthma', data=data).fit()

# print the coefficients
print(Asthma_Cases_lm.params)
print(Asthma_Cases_lm.pvalues)

# create a fitted model in one line
Diabetes_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Diabetes', data=data).fit()

# print the coefficients
print(Diabetes_Cases_lm.params)
print(Diabetes_Cases_lm.pvalues)

# create a fitted model in one line
Teeth_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Six_Plus_Teeth_Extractions', data=data).fit()

# print the coefficients
print(Teeth_Cases_lm.params)
print(Teeth_Cases_lm.pvalues)

# create a fitted model in one line
hbp_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ High_Blood_Pressure', data=data).fit()

# print the coefficients
print(hbp_Cases_lm.params)
print(hbp_Cases_lm.pvalues)

# create a fitted model in one line
multiple_chronic_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Multiple_Chronic_Conditions_Seniors', data=data).fit()

# print the coefficients
print(multiple_chronic_Cases_lm.params)
print(multiple_chronic_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Disease_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Heart_Disease', data=data).fit()

# print the coefficients
print(Heart_Disease_Cases_lm.params)
print(Heart_Disease_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Attack_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Heart_Attack', data=data).fit()

# print the coefficients
print(Heart_Attack_Cases_lm.params)
print(Heart_Attack_Cases_lm.pvalues)

# create a fitted model in one line
Stroke_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Stroke', data=data).fit()

# print the coefficients
print(Stroke_Cases_lm.params)
print(Stroke_Cases_lm.pvalues)

# create a fitted model in one line
High_Cholesterol_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ High_Cholesterol', data=data).fit()

# print the coefficients
print(High_Cholesterol_Cases_lm.params)
print(High_Cholesterol_Cases_lm.pvalues)
# Out:
# Intercept    1023.532626
# Asthma          0.026432
# dtype: float64
# Intercept    0.870269
# Asthma       0.001819
# dtype: float64
# Intercept    2151.051870
# Diabetes        0.017036
# dtype: float64
# Intercept    0.732282
# Diabetes     0.003613
# dtype: float64
# Intercept                    -1229.139024
# Six_Plus_Teeth_Extractions       0.013510
# dtype: float64
# Intercept                     0.852356
# Six_Plus_Teeth_Extractions    0.001291
# dtype: float64
# Intercept              1275.079230
# High_Blood_Pressure       0.006395
# dtype: float64
# Intercept              0.843096
# High_Blood_Pressure    0.003305
# dtype: float64
# Intercept                              698.519161
# Multiple_Chronic_Conditions_Seniors      0.005745
# dtype: float64
# Intercept                              0.90761
# Multiple_Chronic_Conditions_Seniors    0.00070
# dtype: float64
# Intercept        749.486678
# Heart_Disease      0.050063
# dtype: float64
# Intercept        0.909907
# Heart_Disease    0.003835
# dtype: float64
# Intercept       1428.723360
# Heart_Attack       0.044539
# dtype: float64
# Intercept       0.827447
# Heart_Attack    0.004668
# dtype: float64
# Intercept    3964.131085
# Stroke          0.048498
# dtype: float64
# Intercept    0.553365
# Stroke       0.021232
# dtype: float64
# Intercept           917.453825
# High_Cholesterol      0.006376
# dtype: float64
# Intercept           0.884518
# High_Cholesterol    0.001965
# dtype: float64

# %% [markdown]
# ### Multiple Linear Regression

# %%
# create a fitted model with best features identified based on their pvalues
mul_pvalues_best_attributes_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()

# print the coefficients
mul_pvalues_best_attributes_Cases_lm.params
mul_pvalues_best_attributes_Cases_lm.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-69b5f6646436> in <module>
#       1 # create a fitted model with best features identified based on their pvalues
# ----> 2 mul_pvalues_best_attributes_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()
#       3
#       4 # print the coefficients
#       5 mul_pvalues_best_attributes_Cases_lm.params
#
# NameError: name 'smf' is not defined

# %%
# create a fitted model with all features
mul_All_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Native_American_Race + Native_Hawaiian_Race + Employed_People + Mean_Temp_Feb + Median_Age + Air_Pollution + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()

# print the coefficients
mul_All_Cases_lm.params
mul_All_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Cases_Apr_19   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.718
# Method:                 Least Squares   F-statistic:                     7.054
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           1.36e-06
# Time:                        00:39:46   Log-Likelihood:                -561.19
# No. Observations:                  51   AIC:                             1166.
# Df Residuals:                      29   BIC:                             1209.
# Df Model:                          21
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                           -2.084e+04   6.02e+04     -0.346      0.732   -1.44e+05    1.02e+05
# Population                              0.5265      1.025      0.514      0.611      -1.569       2.622
# White_Race                             -0.5080      1.019     -0.499      0.622      -2.592       1.576
# Black_Or_African_Race                  -0.5069      1.018     -0.498      0.622      -2.588       1.575
# Other_Race                             -0.5002      1.021     -0.490      0.628      -2.588       1.588
# Asian_Race                             -0.5160      1.026     -0.503      0.619      -2.613       1.581
# Two_Or_More_Race                       -0.5542      0.996     -0.557      0.582      -2.591       1.482
# Native_American_Race                   -0.4662      1.032     -0.452      0.655      -2.577       1.645
# Native_Hawaiian_Race                   -0.6611      1.097     -0.603      0.551      -2.904       1.582
# Employed_People                        -0.0071      0.048     -0.146      0.885      -0.106       0.092
# Mean_Temp_Feb                         870.9752    495.272      1.759      0.089    -141.970    1883.921
# Median_Age                            587.8955   1471.880      0.399      0.693   -2422.437    3598.228
# Air_Pollution                       -2974.9675   2628.389     -1.132      0.267   -8350.626    2400.691
# Asthma                                 -0.0900      0.040     -2.238      0.033      -0.172      -0.008
# Diabetes                               -0.1797      0.114     -1.582      0.124      -0.412       0.053
# Six_Plus_Teeth_Extractions              0.0444      0.027      1.618      0.116      -0.012       0.100
# High_Blood_Pressure                    -0.0081      0.053     -0.152      0.881      -0.117       0.101
# Multiple_Chronic_Conditions_Seniors     0.0934      0.021      4.544      0.000       0.051       0.135
# Heart_Disease                           0.0783      0.152      0.516      0.609      -0.232       0.388
# Heart_Attack                           -0.0702      0.172     -0.408      0.686      -0.422       0.282
# Stroke                                 -0.3788      0.156     -2.434      0.021      -0.697      -0.060
# High_Cholesterol                       -0.0404      0.060     -0.678      0.503      -0.162       0.082
# ==============================================================================
# Omnibus:                       13.968   Durbin-Watson:                   2.183
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.966
# Skew:                           1.061   Prob(JB):                     0.000341
# Kurtosis:                       4.735   Cond. No.                     3.20e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.2e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# create a fitted model with features identified to have best rsquared values - based on mean
mul_mean_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + High_Cholesterol', data=data).fit()

# print the coefficients
mul_mean_best_rsquared_attributes_Cases_lm.params
mul_mean_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Cases_Apr_19   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     8.903
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           6.56e-08
# Time:                        00:42:19   Log-Likelihood:                -569.20
# No. Observations:                  51   AIC:                             1168.
# Df Residuals:                      36   BIC:                             1197.
# Df Model:                          14
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                            9080.2190   5655.166      1.606      0.117   -2388.990    2.05e+04
# Population                              0.0157      0.041      0.386      0.702      -0.067       0.098
# White_Race                             -0.0216      0.034     -0.626      0.535      -0.091       0.048
# Black_Or_African_Race                  -0.0138      0.034     -0.400      0.692      -0.084       0.056
# Other_Race                              0.0001      0.040      0.003      0.998      -0.082       0.082
# Asian_Race                             -0.0410      0.054     -0.755      0.455      -0.151       0.069
# Employed_People                         0.0129      0.046      0.278      0.783      -0.081       0.107
# Asthma                                 -0.0929      0.037     -2.520      0.016      -0.168      -0.018
# Diabetes                               -0.1604      0.110     -1.453      0.155      -0.384       0.064
# Six_Plus_Teeth_Extractions              0.0814      0.025      3.217      0.003       0.030       0.133
# High_Blood_Pressure                    -0.0974      0.042     -2.306      0.027      -0.183      -0.012
# Multiple_Chronic_Conditions_Seniors     0.0967      0.020      4.922      0.000       0.057       0.137
# Heart_Disease                          -0.0624      0.145     -0.431      0.669      -0.356       0.231
# Heart_Attack                           -0.1531      0.159     -0.965      0.341      -0.475       0.169
# High_Cholesterol                        0.0434      0.054      0.811      0.423      -0.065       0.152
# ==============================================================================
# Omnibus:                       14.967   Durbin-Watson:                   2.111
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               20.588
# Skew:                           0.984   Prob(JB):                     3.38e-05
# Kurtosis:                       5.411   Cond. No.                     2.86e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.86e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# create a fitted model with features identified to have best rsquared values - based on median
mul_median_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_Apr_19 ~ Population + Black_Or_African_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + High_Cholesterol', data=data).fit()

# print the coefficients
mul_median_best_rsquared_attributes_Cases_lm.params
mul_median_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Cases_Apr_19   R-squared:                       0.758
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     12.50
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           1.82e-09
# Time:                        00:43:14   Log-Likelihood:                -571.20
# No. Observations:                  51   AIC:                             1164.
# Df Residuals:                      40   BIC:                             1186.
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                            9919.4366   5251.213      1.889      0.066    -693.660    2.05e+04
# Population                              0.0323      0.023      1.378      0.176      -0.015       0.080
# Black_Or_African_Race                   0.0113      0.008      1.398      0.170      -0.005       0.028
# Employed_People                        -0.0319      0.034     -0.947      0.349      -0.100       0.036
# Asthma                                 -0.0906      0.035     -2.555      0.015      -0.162      -0.019
# Diabetes                               -0.2263      0.096     -2.351      0.024      -0.421      -0.032
# Six_Plus_Teeth_Extractions              0.0704      0.024      2.968      0.005       0.022       0.118
# High_Blood_Pressure                    -0.1093      0.040     -2.758      0.009      -0.189      -0.029
# Multiple_Chronic_Conditions_Seniors     0.0867      0.016      5.259      0.000       0.053       0.120
# Heart_Disease                          -0.0924      0.137     -0.673      0.505      -0.370       0.185
# High_Cholesterol                        0.0272      0.049      0.554      0.583      -0.072       0.126
# ==============================================================================
# Omnibus:                       10.295   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               12.826
# Skew:                           0.693   Prob(JB):                      0.00164
# Kurtosis:                       5.029   Cond. No.                     2.36e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.36e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
