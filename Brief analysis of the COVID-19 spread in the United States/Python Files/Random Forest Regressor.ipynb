# %%
from scipy.io import loadmat
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\Maverick\Desktop\Machine Learning\Project\Datasetu.csv')
data.head()
# Out:
#    rank       State  Cases_Feb_29  Cases_Mar_17  Cases_Mar_31  Cases_Apr_19  \
# 0    24     Alabama             0            39           999          4837
# 1    49      Alaska             0             6           133           319
# 2    14     Arizona             1            20          1298          4929
# 3    33    Arkansas             0            22           564          1777
# 4     1  California            28           732          8582         30852
#
#    Cases_May_02  Population   Density    White_Race  ...  Air_Pollution  \
# 0          7611     4908621   96.9221  3.347189e+06  ...            7.4
# 1           365      734002    1.2863  4.759269e+05  ...            8.4
# 2          8364     7378494   64.9550  5.697673e+06  ...            9.7
# 3          3372     3038999   58.4030  2.340029e+06  ...            7.1
# 4         53606    39937489  256.3727  2.400243e+07  ...           11.9
#
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
#dataframe=pd.read_csv(r'C:\Users\ssharm58\Downloads\ML Project\Datasetu.population.csv')
#dataframe1=pd.read_csv(r'C:\Users\ssharm58\Downloads\ML Project\Datasetu.csv')
dataframe=data['Population']
dataframe1=data['Cases_Feb_29']
dataframe2=data['Cases_Mar_17']
dataframe3=data['Cases_Mar_31']
dataframe4=data['Cases_Apr_19']
dataframe5=data['Cases_May_02']

# %%
# to find relation between X = 'Population' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

# %%
import pandas
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

# %%
X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)

# %%
X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)
# Out:
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
#random forest
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor,AdaBoostRegressor
rf=RandomForestRegressor(n_estimators=10)
rf.fit(X_train,Y_train)
# Out:
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rf_Population_test_score1 = rf.score(X_test,Y_test)

# %%
# to find relation between X = 'Population' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Population_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Population' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Population_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Population' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Population_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Population' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Population_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'Asian_Race' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asian_Race_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'Asian_Race' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asian_Race_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Asian_Race' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asian_Race_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Asian_Race' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asian_Race_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Asian_Race' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asian_Race_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'White_Race' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_White_Race_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'White_Race' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_White_Race_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'White_Race' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_White_Race_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'White_Race' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_White_Race_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'White_Race' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_White_Race_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Black_Or_African_Race_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Black_Or_African_Race_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Black_Or_African_Race_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Black_Or_African_Race_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Black_Or_African_Race_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'Employed_People' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Employed_People_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'Employed_People' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Employed_People_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Employed_People' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Employed_People_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Employed_People' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Employed_People_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Employed_People' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Employed_People_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'Asthma' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asthma_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'Asthma' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asthma_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Asthma' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asthma_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Asthma' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asthma_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Asthma' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Asthma_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'Diabetes' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Diabetes_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'Diabetes' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Diabetes_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Diabetes' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Diabetes_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Diabetes' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Diabetes_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Diabetes' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Diabetes_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Six_Plus_Teeth_Extractions_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Six_Plus_Teeth_Extractions_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Six_Plus_Teeth_Extractions_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Six_Plus_Teeth_Extractions_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Six_Plus_Teeth_Extractions_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Blood_Pressure_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Blood_Pressure_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Blood_Pressure_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Blood_Pressure_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Blood_Pressure_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Multiple_Chronic_Conditions_Seniors_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Multiple_Chronic_Conditions_Seniors_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Multiple_Chronic_Conditions_Seniors_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Multiple_Chronic_Conditions_Seniors_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_Multiple_Chronic_Conditions_Seniors_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
# to find relation between X = 'High_Cholesterol' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Cholesterol_test_score1 = rf.score(X_test,Y_test)

#--------------------------------------------------------------------------------------
# to find relation between X = 'High_Cholesterol' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Cholesterol_test_score2 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'High_Cholesterol' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Cholesterol_test_score3 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'High_Cholesterol' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Cholesterol_test_score4 = rf.score(X_test,Y_test)

# --------------------------------------------------------------------------------------
# to find relation between X = 'High_Cholesterol' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

rf.fit(X_train,Y_train)
rf_High_Cholesterol_test_score5 = rf.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# C:\Users\Maverick\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
rf_compare = pd.DataFrame( 
    {  'Dataset' : ['Cases_Feb_29', 'Cases_Mar_17', 'Cases_Mar_31', 'Cases_Apr_19', 'Cases_May_02'], 
       'Cases predicted with Population' : [rf_Population_test_score1, rf_Population_test_score2, rf_Population_test_score3, rf_Population_test_score4, rf_Population_test_score5],
       'Cases predicted with Asian Race' : [rf_Asian_Race_test_score1, rf_Asian_Race_test_score2, rf_Asian_Race_test_score3, rf_Asian_Race_test_score4, rf_Asian_Race_test_score5],
       'Cases predicted with White Race' : [rf_White_Race_test_score1, rf_White_Race_test_score2, rf_White_Race_test_score3, rf_White_Race_test_score4, rf_White_Race_test_score5],
       'Cases predicted with Black or African Race' : [rf_Black_Or_African_Race_test_score1, rf_Black_Or_African_Race_test_score2, rf_Black_Or_African_Race_test_score3, rf_Black_Or_African_Race_test_score4, rf_Black_Or_African_Race_test_score5],
       'Cases predicted with Employed People' : [rf_Employed_People_test_score1, rf_Employed_People_test_score2, rf_Employed_People_test_score3, rf_Employed_People_test_score4, rf_Employed_People_test_score5],
       'Cases predicted with Asthma' : [rf_Asthma_test_score1, rf_Asthma_test_score2, rf_Asthma_test_score3, rf_Asthma_test_score4, rf_Asthma_test_score5],
       'Cases predicted with Diabetes' : [rf_Diabetes_test_score1, rf_Diabetes_test_score2, rf_Diabetes_test_score3, rf_Diabetes_test_score4, rf_Diabetes_test_score5],
       'Cases predicted with Six Plus Teeth Extractions' : [rf_Six_Plus_Teeth_Extractions_test_score1, rf_Six_Plus_Teeth_Extractions_test_score2, rf_Six_Plus_Teeth_Extractions_test_score3, rf_Six_Plus_Teeth_Extractions_test_score4, rf_Six_Plus_Teeth_Extractions_test_score5],
       'Cases predicted with High Blood Pressure' : [rf_High_Blood_Pressure_test_score1, rf_High_Blood_Pressure_test_score2, rf_High_Blood_Pressure_test_score3, rf_High_Blood_Pressure_test_score4, rf_High_Blood_Pressure_test_score5],
       'Cases predicted with Multiple_Chronic_Conditions_Seniors' : [rf_Multiple_Chronic_Conditions_Seniors_test_score1, rf_Multiple_Chronic_Conditions_Seniors_test_score2, rf_Multiple_Chronic_Conditions_Seniors_test_score3, rf_Multiple_Chronic_Conditions_Seniors_test_score4, rf_Multiple_Chronic_Conditions_Seniors_test_score5],
       'Cases predicted with High_Cholesterol' : [rf_High_Cholesterol_test_score1, rf_High_Cholesterol_test_score2, rf_High_Cholesterol_test_score3, rf_High_Cholesterol_test_score4, rf_High_Cholesterol_test_score5]
     
    }) 
print('Random Forest Regressor Scores:\n')
print('Cases were predicted based on the following attributes:\n')
print(rf_compare)
rf_compare
# Out:
# Random Forest Regressor Scores:
#
# Cases were predicted based on the following attributes:
#
#         Dataset  Cases predicted with Population  \
# 0  Cases_Feb_29                         0.176296
# 1  Cases_Mar_17                        -7.228166
# 2  Cases_Mar_31                        -0.847520
# 3  Cases_Apr_19                        -1.365974
# 4  Cases_May_02                        -0.253466
#
#    Cases predicted with Asian Race  Cases predicted with White Race  \
# 0                        -0.191752                        -0.206967
# 1                        -3.295564                        -0.929426
# 2                        -3.100464                        -0.861602
# 3                        -0.236384                        -1.368715
# 4                        -0.533740                        -0.143683
#
#    Cases predicted with Black or African Race  \
# 0                                    0.189269
# 1                                   -2.895456
# ...

# %%
rf_compare.to_csv(r'C:\Users\Maverick\Desktop\Machine Learning\Project\random_forest_regressor_scores.csv')
