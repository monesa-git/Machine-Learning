# %%
# Load libraries
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# read data into a DataFrame
data = pd.read_csv('C:/Users/Maverick/Desktop/Machine Learning/Project/Datasetu.csv', index_col=0)
data.head()
# Out:
#            State  Cases_Feb_29  Cases_Mar_17  Cases_Mar_31  Cases_Apr_19  \
# rank
# 24       Alabama             0            39           999          4837
# 49        Alaska             0             6           133           319
# 14       Arizona             1            20          1298          4929
# 33      Arkansas             0            22           564          1777
# 1     California            28           732          8582         30852
#
#       Cases_May_02  Population   Density    White_Race  Black_Or_African_Race  \
# rank
# 24            7611     4908621   96.9221  3.347189e+06           1.304711e+06
# 49             365      734002    1.2863  4.759269e+05           2.400187e+04
# 14            8364     7378494   64.9550  5.697673e+06           3.239159e+05
# 33            3372     3038999   58.4030  2.340029e+06           4.683097e+05
# 1            53606    39937489  256.3727  2.400243e+07           2.312381e+06
#
# ...

# %% [markdown]
# ### Single Linear Regression
# To find the attributes that have relation to the number of cases.
# The coefficient and pvalue is found out.

# %%
# this is the standard import if you're using "formula notation" (similar to R)
import statsmodels.formula.api as smf

# create a fitted model in one line
Pop_Cases_lm = smf.ols(formula='Cases_May_02 ~ Population', data=data).fit()

# print the coefficients
print(Pop_Cases_lm.params)
print(Pop_Cases_lm.pvalues)
# Out:
# Intercept     3231.363160
# Population       0.002936
# dtype: float64
# Intercept     0.689573
# Population    0.000765
# dtype: float64

# %%
# create a fitted model in one line
Density_Cases_lm = smf.ols(formula='Cases_Per_Sq_Mile_May_02 ~ Density', data=data).fit()

# print the coefficients
print(Density_Cases_lm.params)
print(Density_Cases_lm.pvalues)
# Out:
# Intercept   -7645.874419
# Density        70.043507
# dtype: float64
# Intercept    2.045554e-01
# Density      4.260541e-25
# dtype: float64

# %%
# create a fitted model in one line
White_Race_Cases_lm = smf.ols(formula='Cases_May_02 ~ White_Race', data=data).fit()

# print the coefficients
print(White_Race_Cases_lm.params)
print(White_Race_Cases_lm.pvalues)
# Out:
# Intercept     2752.053626
# White_Race       0.004136
# dtype: float64
# Intercept     0.746414
# White_Race    0.001582
# dtype: float64

# %%
# create a fitted model in one line
Black_Or_African_Cases_lm = smf.ols(formula='Cases_May_02 ~ Black_Or_African_Race', data=data).fit()

# print the coefficients
print(Black_Or_African_Cases_lm.params)
print(Black_Or_African_Cases_lm.pvalues)
# Out:
# Intercept                2743.247738
# Black_Or_African_Race       0.023786
# dtype: float64
# Intercept                0.722104
# Black_Or_African_Race    0.000223
# dtype: float64

# %%
# create a fitted model in one line
Other_Race_Cases_lm = smf.ols(formula='Cases_May_02 ~ Other_Race', data=data).fit()

# print the coefficients
print(Other_Race_Cases_lm.params)
print(Other_Race_Cases_lm.pvalues)
# Out:
# Intercept     15101.925711
# Other_Race        0.022714
# dtype: float64
# Intercept     0.028919
# Other_Race    0.004840
# dtype: float64

# %%
# create a fitted model in one line
Asian_Race_Cases_lm = smf.ols(formula='Cases_May_02 ~ Asian_Race', data=data).fit()

# print the coefficients
print(Asian_Race_Cases_lm.params)
print(Asian_Race_Cases_lm.pvalues)
# Out:
# Intercept     14505.545061
# Asian_Race        0.022138
# dtype: float64
# Intercept     0.038086
# Asian_Race    0.005256
# dtype: float64

# %%
# create a fitted model in one line
Two_Or_More_Cases_lm = smf.ols(formula='Cases_May_02 ~ Two_Or_More_Race', data=data).fit()

# print the coefficients
print(Two_Or_More_Cases_lm.params)
print(Two_Or_More_Cases_lm.pvalues)
# Out:
# Intercept           10131.558322
# Two_Or_More_Race        0.058125
# dtype: float64
# Intercept           0.200564
# Two_Or_More_Race    0.010295
# dtype: float64

# %%
# create a fitted model in one line
Native_American_Race_Cases_lm = smf.ols(formula='Cases_May_02 ~ Native_American_Race', data=data).fit()

# print the coefficients
print(Native_American_Race_Cases_lm.params)
print(Native_American_Race_Cases_lm.pvalues)
# Out:
# Intercept               20339.280585
# Native_American_Race        0.036128
# dtype: float64
# Intercept               0.018793
# Native_American_Race    0.690740
# dtype: float64

# %%
# create a fitted model in one line
Native_Hawaiian_Race_Cases_lm = smf.ols(formula='Cases_May_02 ~ Native_Hawaiian_Race', data=data).fit()

# print the coefficients
print(Native_Hawaiian_Race_Cases_lm.params)
print(Native_Hawaiian_Race_Cases_lm.pvalues)
# Out:
# Intercept               21667.248893
# Native_Hawaiian_Race        0.054959
# dtype: float64
# Intercept               0.004619
# Native_Hawaiian_Race    0.813953
# dtype: float64

# %%
# create a fitted model in one line
Employed_People_Cases_lm = smf.ols(formula='Cases_May_02 ~ Employed_People', data=data).fit()

# print the coefficients
print(Employed_People_Cases_lm.params)
print(Employed_People_Cases_lm.pvalues)
# Out:
# Intercept          2505.624709
# Employed_People       0.006428
# dtype: float64
# Intercept          0.757601
# Employed_People    0.000596
# dtype: float64

# %%
# create a fitted model in one line
UnEmployed_People_Cases_lm = smf.ols(formula='Cases_May_02 ~ UnEmployed_People', data=data).fit()

# print the coefficients
print(UnEmployed_People_Cases_lm.params)
print(UnEmployed_People_Cases_lm.pvalues)
# Out:
# Intercept            3906.658336
# UnEmployed_People       0.005387
# dtype: float64
# Intercept            0.628020
# UnEmployed_People    0.000965
# dtype: float64

# %%
# create a fitted model in one line
Mean_Temp_Mar_Cases_lm = smf.ols(formula='Cases_May_02 ~ Mean_Temp_Apr', data=data).fit()

# print the coefficients
print(Mean_Temp_Mar_Cases_lm.params)
print(Mean_Temp_Mar_Cases_lm.pvalues)
# Out:
# Intercept        16917.008067
# Mean_Temp_Apr      100.113834
# dtype: float64
# Intercept        0.705497
# Mean_Temp_Apr    0.902962
# dtype: float64

# %%
# create a fitted model in one line
Median_Age_Cases_lm = smf.ols(formula='Cases_May_02 ~ Median_Age', data=data).fit()

# print the coefficients
print(Median_Age_Cases_lm.params)
print(Median_Age_Cases_lm.pvalues)
# Out:
# Intercept    -31550.177020
# Median_Age     1408.511886
# dtype: float64
# Intercept     0.769949
# Median_Age    0.617227
# dtype: float64

# %%
# create a fitted model in one line
Air_Pollution_Cases_lm = smf.ols(formula='Cases_May_02 ~ Air_Pollution', data=data).fit()

# print the coefficients
print(Air_Pollution_Cases_lm.params)
print(Air_Pollution_Cases_lm.pvalues)
# Out:
# Intercept        55792.491373
# Air_Pollution    -4419.609369
# dtype: float64
# Intercept        0.139099
# Air_Pollution    0.363310
# dtype: float64

# %%
# create a fitted model in one line
Asthma_Cases_lm = smf.ols(formula='Cases_May_02 ~ Asthma', data=data).fit()

# print the coefficients
print(Asthma_Cases_lm.params)
print(Asthma_Cases_lm.pvalues)

# create a fitted model in one line
Diabetes_Cases_lm = smf.ols(formula='Cases_May_02 ~ Diabetes', data=data).fit()

# print the coefficients
print(Diabetes_Cases_lm.params)
print(Diabetes_Cases_lm.pvalues)

# create a fitted model in one line
Teeth_Cases_lm = smf.ols(formula='Cases_May_02 ~ Six_Plus_Teeth_Extractions', data=data).fit()

# print the coefficients
print(Teeth_Cases_lm.params)
print(Teeth_Cases_lm.pvalues)

# create a fitted model in one line
hbp_Cases_lm = smf.ols(formula='Cases_May_02 ~ High_Blood_Pressure', data=data).fit()

# print the coefficients
print(hbp_Cases_lm.params)
print(hbp_Cases_lm.pvalues)

# create a fitted model in one line
multiple_chronic_Cases_lm = smf.ols(formula='Cases_May_02 ~ Multiple_Chronic_Conditions_Seniors', data=data).fit()

# print the coefficients
print(multiple_chronic_Cases_lm.params)
print(multiple_chronic_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Disease_Cases_lm = smf.ols(formula='Cases_May_02 ~ Heart_Disease', data=data).fit()

# print the coefficients
print(Heart_Disease_Cases_lm.params)
print(Heart_Disease_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Attack_Cases_lm = smf.ols(formula='Cases_May_02 ~ Heart_Attack', data=data).fit()

# print the coefficients
print(Heart_Attack_Cases_lm.params)
print(Heart_Attack_Cases_lm.pvalues)

# create a fitted model in one line
Stroke_Cases_lm = smf.ols(formula='Cases_May_02 ~ Stroke', data=data).fit()

# print the coefficients
print(Stroke_Cases_lm.params)
print(Stroke_Cases_lm.pvalues)

# create a fitted model in one line
High_Cholesterol_Cases_lm = smf.ols(formula='Cases_May_02 ~ High_Cholesterol', data=data).fit()

# print the coefficients
print(High_Cholesterol_Cases_lm.params)
print(High_Cholesterol_Cases_lm.pvalues)
# Out:
# Intercept    2706.083019
# Asthma          0.037780
# dtype: float64
# Intercept    0.739051
# Asthma       0.000660
# dtype: float64
# Intercept    4400.246094
# Diabetes        0.024239
# dtype: float64
# Intercept    0.590878
# Diabetes     0.001588
# dtype: float64
# Intercept                    -8.530860
# Six_Plus_Teeth_Extractions    0.018883
# dtype: float64
# Intercept                     0.999208
# Six_Plus_Teeth_Extractions    0.000606
# dtype: float64
# Intercept              3010.695389
# High_Blood_Pressure       0.009167
# dtype: float64
# Intercept              0.718909
# High_Blood_Pressure    0.001303
# dtype: float64
# Intercept                              2430.902001
# Multiple_Chronic_Conditions_Seniors       0.008135
# dtype: float64
# Intercept                              0.755132
# Multiple_Chronic_Conditions_Seniors    0.000244
# dtype: float64
# Intercept        2534.440178
# Heart_Disease       0.070769
# dtype: float64
# Intercept        0.769063
# ...

# %% [markdown]
# ### Multiple Linear Regression

# %%
# create a fitted model with best features identified based on their pvalues
mul_pvalues_best_attributes_Cases_lm = smf.ols(formula='Cases_May_02 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()

# print the coefficients
mul_pvalues_best_attributes_Cases_lm.params
mul_pvalues_best_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_May_02   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     9.604
# Date:                Sun, 03 May 2020   Prob (F-statistic):           2.28e-08
# Time:                        16:46:50   Log-Likelihood:                -577.97
# No. Observations:                  51   AIC:                             1190.
# Df Residuals:                      34   BIC:                             1223.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with all features
mul_All_Cases_lm = smf.ols(formula='Cases_May_02 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Native_American_Race + Native_Hawaiian_Race + Employed_People + Mean_Temp_Apr + Median_Age + Air_Pollution + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()

# print the coefficients
mul_All_Cases_lm.params
mul_All_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_May_02   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.715
# Method:                 Least Squares   F-statistic:                     6.962
# Date:                Sun, 03 May 2020   Prob (F-statistic):           1.57e-06
# Time:                        16:46:40   Log-Likelihood:                -575.67
# No. Observations:                  51   AIC:                             1195.
# Df Residuals:                      29   BIC:                             1238.
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with features identified to have best rsquared values - based on mean
mul_mean_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_May_02 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + High_Cholesterol', data=data).fit()

# print the coefficients
mul_mean_best_rsquared_attributes_Cases_lm.params
mul_mean_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_May_02   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     9.820
# Date:                Sun, 03 May 2020   Prob (F-statistic):           1.85e-08
# Time:                        16:48:11   Log-Likelihood:                -581.43
# No. Observations:                  51   AIC:                             1193.
# Df Residuals:                      36   BIC:                             1222.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with features identified to have best rsquared values - based on median
mul_median_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_May_02 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + High_Cholesterol', data=data).fit()

# print the coefficients
mul_median_best_rsquared_attributes_Cases_lm.params
mul_median_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_May_02   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     9.820
# Date:                Sun, 03 May 2020   Prob (F-statistic):           1.85e-08
# Time:                        16:49:37   Log-Likelihood:                -581.43
# No. Observations:                  51   AIC:                             1193.
# Df Residuals:                      36   BIC:                             1222.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...
