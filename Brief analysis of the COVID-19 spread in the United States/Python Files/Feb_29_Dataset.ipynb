# %%
# Load libraries
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# read data into a DataFrame
data = pd.read_csv('C:/Users/Maverick/Desktop/Machine Learning/Project/Datasetu.csv', index_col=0)
data.head()
# Out:
#            State  Cases_Feb_29  Cases_Mar_17  Cases_Mar_31  Cases_Apr_19  \
# rank
# 24       Alabama             0            39           999          4837
# 49        Alaska             0             6           133           319
# 14       Arizona             1            20          1298          4929
# 33      Arkansas             0            22           564          1777
# 1     California            28           732          8582         30852
#
#       Cases_May_02  Population   Density    White_Race  Black_Or_African_Race  \
# rank
# 24            7611     4908621   96.9221  3.347189e+06           1.304711e+06
# 49             365      734002    1.2863  4.759269e+05           2.400187e+04
# 14            8364     7378494   64.9550  5.697673e+06           3.239159e+05
# 33            3372     3038999   58.4030  2.340029e+06           4.683097e+05
# 1            53606    39937489  256.3727  2.400243e+07           2.312381e+06
#
# ...

# %% [markdown]
# ### Single Linear Regression
# To find the attributes that have relation to the number of cases.
# The coefficient and pvalue is found out.

# %%
# this is the standard import if you're using "formula notation" (similar to R)
import statsmodels.formula.api as smf

# create a fitted model in one line
Pop_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Population', data=data).fit()

# print the coefficients
print(Pop_Cases_lm.params)
print(Pop_Cases_lm.pvalues)
# Out:
# Intercept    -1.335033e+00
# Population    4.167786e-07
# dtype: float64
# Intercept     4.798450e-02
# Population    1.054589e-07
# dtype: float64

# %%
# create a fitted model in one line
Density_Cases_lm = smf.ols(formula='Cases_Per_Sq_Mile_Feb_29 ~ Density', data=data).fit()

# print the coefficients
print(Pop_Density_lm.params)
print(Pop_Density_lm.pvalues)
# Out:
# Intercept    3.240357e-03
# Density      1.459359e-07
# dtype: float64
# Intercept    0.105117
# Density      0.900677
# dtype: float64

# %%
# create a fitted model in one line
White_Race_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ White_Race', data=data).fit()

# print the coefficients
print(Pop_White_Race_lm.params)
print(Pop_White_Race_lm.pvalues)
# Out:
# Intercept    -1.326462e+00
# White_Race    5.708366e-07
# dtype: float64
# Intercept     0.072958
# White_Race    0.000002
# dtype: float64

# %%
# create a fitted model in one line
Black_Or_African_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Black_Or_African_Race', data=data).fit()

# print the coefficients
print(Pop_Black_Or_African_lm.params)
print(Pop_Black_Or_African_lm.pvalues)
# Out:
# Intercept                0.428197
# Black_Or_African_Race    0.000001
# dtype: float64
# Intercept                0.609919
# Black_Or_African_Race    0.082974
# dtype: float64

# %%
# create a fitted model in one line
Other_Race_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Other_Race', data=data).fit()

# print the coefficients
print(Pop_Other_Race_lm.params)
print(Pop_Other_Race_lm.pvalues)
# Out:
# Intercept    -0.120698
# Other_Race    0.000005
# dtype: float64
# Intercept     7.640209e-01
# Other_Race    8.389346e-14
# dtype: float64

# %%
# create a fitted model in one line
Other_Race_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Asian_Race', data=data).fit()

# print the coefficients
print(Pop_Other_Race_lm.params)
print(Pop_Other_Race_lm.pvalues)
# Out:
# Intercept    -0.257164
# Asian_Race    0.000005
# dtype: float64
# Intercept     5.290031e-01
# Asian_Race    9.135211e-14
# dtype: float64

# %%
# create a fitted model in one line
Two_Or_More_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Two_Or_More_Race', data=data).fit()

# print the coefficients
print(Pop_Other_Race_lm.params)
print(Pop_Other_Race_lm.pvalues)
# Out:
# Intercept    -0.257164
# Asian_Race    0.000005
# dtype: float64
# Intercept     5.290031e-01
# Asian_Race    9.135211e-14
# dtype: float64

# %%
# create a fitted model in one line
Native_American_Race_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Native_American_Race', data=data).fit()

# print the coefficients
print(Pop_Native_American_Race_lm.params)
print(Pop_Native_American_Race_lm.pvalues)
# Out:
# Intercept              -0.163748
# Native_American_Race    0.000028
# dtype: float64
# Intercept               0.822629
# Native_American_Race    0.000745
# dtype: float64

# %%
# create a fitted model in one line
Native_Hawaiian_Race_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Native_Hawaiian_Race', data=data).fit()

# print the coefficients
print(Pop_Native_Hawaiian_Race_lm.params)
print(Pop_Native_Hawaiian_Race_lm.pvalues)
# Out:
# Intercept               0.187825
# Native_Hawaiian_Race    0.000102
# dtype: float64
# Intercept               7.323283e-01
# Native_Hawaiian_Race    3.943698e-07
# dtype: float64

# %%
# create a fitted model in one line
Employed_People_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Employed_People', data=data).fit()

# print the coefficients
print(Pop_Employed_People_lm.params)
print(Pop_Employed_People_lm.pvalues)
# Out:
# Intercept         -1.387588e+00
# Employed_People    8.959372e-07
# dtype: float64
# Intercept          4.188326e-02
# Employed_People    1.069073e-07
# dtype: float64

# %%
# create a fitted model in one line
UnEmployed_People_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ UnEmployed_People', data=data).fit()

# print the coefficients
print(UnEmployed_People_Cases_lm.params)
print(UnEmployed_People_Cases_lm.pvalues)
# Out:
# Intercept           -1.281325e+00
# UnEmployed_People    7.769577e-07
# dtype: float64
# Intercept            5.560719e-02
# UnEmployed_People    1.106095e-07
# dtype: float64

# %%
# create a fitted model in one line
Mean_Temp_Feb_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Mean_Temp_Feb', data=data).fit()

# print the coefficients
print(Mean_Temp_Feb_Cases_lm.params)
print(Mean_Temp_Feb_Cases_lm.pvalues)
# Out:
# Intercept       -1.430716
# Mean_Temp_Feb    0.075644
# dtype: float64
# Intercept        0.519976
# Mean_Temp_Feb    0.190155
# dtype: float64

# %%
# create a fitted model in one line
Median_Age_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Median_Age', data=data).fit()

# print the coefficients
print(Median_Age_Cases_lm.params)
print(Median_Age_Cases_lm.pvalues)
# Out:
# Intercept     18.445869
# Median_Age    -0.446510
# dtype: float64
# Intercept     0.076519
# Median_Age    0.099688
# dtype: float64

# %%
# create a fitted model in one line
Air_Pollution_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Air_Pollution', data=data).fit()

# print the coefficients
print(Air_Pollution_Cases_lm.params)
print(Air_Pollution_Cases_lm.pvalues)
# Out:
# Intercept       -5.321194
# Air_Pollution    0.883491
# dtype: float64
# Intercept        0.136504
# Air_Pollution    0.058607
# dtype: float64

# %%
# create a fitted model in one line
Asthma_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Asthma', data=data).fit()

# print the coefficients
print(Asthma_Cases_lm.params)
print(Asthma_Cases_lm.pvalues)

# create a fitted model in one line
Diabetes_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Diabetes', data=data).fit()

# print the coefficients
print(Diabetes_Cases_lm.params)
print(Diabetes_Cases_lm.pvalues)

# create a fitted model in one line
Diabetes_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Diabetes', data=data).fit()

# print the coefficients
print(Diabetes_Cases_lm.params)
print(Diabetes_Cases_lm.pvalues)

# create a fitted model in one line
Teeth_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Six_Plus_Teeth_Extractions', data=data).fit()

# print the coefficients
print(Teeth_Cases_lm.params)
print(Teeth_Cases_lm.pvalues)

# create a fitted model in one line
hbp_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ High_Blood_Pressure', data=data).fit()

# print the coefficients
print(hbp_Cases_lm.params)
print(hbp_Cases_lm.pvalues)

# create a fitted model in one line
multiple_chronic_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Multiple_Chronic_Conditions_Seniors', data=data).fit()

# print the coefficients
print(multiple_chronic_Cases_lm.params)
print(multiple_chronic_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Disease_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Heart_Disease', data=data).fit()

# print the coefficients
print(Heart_Disease_Cases_lm.params)
print(Heart_Disease_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Attack_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Heart_Attack', data=data).fit()

# print the coefficients
print(Heart_Attack_Cases_lm.params)
print(Heart_Attack_Cases_lm.pvalues)

# create a fitted model in one line
Stroke_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Stroke', data=data).fit()

# print the coefficients
print(Stroke_Cases_lm.params)
print(Stroke_Cases_lm.pvalues)

# create a fitted model in one line
High_Cholesterol_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ High_Cholesterol', data=data).fit()

# print the coefficients
print(High_Cholesterol_Cases_lm.params)
print(High_Cholesterol_Cases_lm.pvalues)
# Out:
# Intercept   -1.016410
# Asthma       0.000005
# dtype: float64
# Intercept    0.167123
# Asthma       0.000009
# dtype: float64
# Intercept   -1.107375
# Diabetes     0.000003
# dtype: float64
# Intercept    0.117114
# Diabetes     0.000002
# dtype: float64
# Intercept   -1.107375
# Diabetes     0.000003
# dtype: float64
# Intercept    0.117114
# Diabetes     0.000002
# dtype: float64
# Intercept                    -0.802544
# Six_Plus_Teeth_Extractions    0.000002
# dtype: float64
# Intercept                     0.340399
# Six_Plus_Teeth_Extractions    0.000605
# dtype: float64
# Intercept             -1.247246
# High_Blood_Pressure    0.000001
# dtype: float64
# Intercept              0.087055
# High_Blood_Pressure    0.000002
# dtype: float64
# Intercept                             -9.450090e-01
# Multiple_Chronic_Conditions_Seniors    9.484767e-07
# dtype: float64
# Intercept                              0.184046
# Multiple_Chronic_Conditions_Seniors    0.000005
# dtype: float64
# ...

# %% [markdown]
# ### Multiple Linear Regression

# %%
# create a fitted model with best features identified based on their pvalues
mul_pvalues_best_attributes_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ White_Race + Native_American_Race + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke', data=data).fit()

# print the coefficients
mul_pvalues_best_attributes_Cases_lm.params
mul_pvalues_best_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Feb_29   R-squared:                       0.790
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     15.05
# Date:                Sun, 03 May 2020   Prob (F-statistic):           1.21e-10
# Time:                        17:33:33   Log-Likelihood:                -110.70
# No. Observations:                  51   AIC:                             243.4
# Df Residuals:                      40   BIC:                             264.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with all features
mul_All_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Native_American_Race + Native_Hawaiian_Race + Employed_People + Mean_Temp_Feb + Median_Age + Air_Pollution + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()

# print the coefficients
mul_All_Cases_lm.params
mul_All_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Feb_29   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.736
# Method:                 Least Squares   F-statistic:                     7.645
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           5.71e-07
# Time:                        00:21:49   Log-Likelihood:                -102.62
# No. Observations:                  51   AIC:                             249.2
# Df Residuals:                      29   BIC:                             291.7
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with features identified to have best rsquared values - based on mean
mul_mean_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Population + Other_Race + Asian_Race + Two_Or_More_Race + Native_Hawaiian_Race + Employed_People + Asthma + Diabetes + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + High_Cholesterol', data=data).fit()

# print the coefficients
mul_mean_best_rsquared_attributes_Cases_lm.params
mul_mean_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Feb_29   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     11.22
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           5.65e-09
# Time:                        00:24:46   Log-Likelihood:                -114.11
# No. Observations:                  51   AIC:                             252.2
# Df Residuals:                      39   BIC:                             275.4
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with features identified to have best rsquared values - based on median
mul_median_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_Feb_29 ~ Population + Other_Race + Asian_Race + Two_Or_More_Race + Native_Hawaiian_Race + Employed_People + Diabetes + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + High_Cholesterol', data=data).fit()

# print the coefficients
mul_median_best_rsquared_attributes_Cases_lm.params
mul_median_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Feb_29   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.696
# Method:                 Least Squares   F-statistic:                     12.42
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           2.00e-09
# Time:                        00:26:33   Log-Likelihood:                -114.48
# No. Observations:                  51   AIC:                             251.0
# Df Residuals:                      40   BIC:                             272.2
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...
