# %%
from scipy.io import loadmat
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\Maverick\Desktop\Machine Learning\Project\Datasetu.csv')
data.head()
# Out:
#    rank       State  Cases_Feb_29  Cases_Mar_17  Cases_Mar_31  Cases_Apr_19  \
# 0    24     Alabama             0            39           999          4837
# 1    49      Alaska             0             6           133           319
# 2    14     Arizona             1            20          1298          4929
# 3    33    Arkansas             0            22           564          1777
# 4     1  California            28           732          8582         30852
#
#    Cases_May_02  Population   Density    White_Race  ...  Air_Pollution  \
# 0          7611     4908621   96.9221  3.347189e+06  ...            7.4
# 1           365      734002    1.2863  4.759269e+05  ...            8.4
# 2          8364     7378494   64.9550  5.697673e+06  ...            9.7
# 3          3372     3038999   58.4030  2.340029e+06  ...            7.1
# 4         53606    39937489  256.3727  2.400243e+07  ...           11.9
#
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
#dataframe=pd.read_csv(r'C:\Users\ssharm58\Downloads\ML Project\Datasetu.population.csv')
#dataframe1=pd.read_csv(r'C:\Users\ssharm58\Downloads\ML Project\Datasetu.csv')
dataframe=data['Population']
dataframe1=data['Cases_Feb_29']
dataframe2=data['Cases_Mar_17']
dataframe3=data['Cases_Mar_31']
dataframe4=data['Cases_Apr_19']
dataframe5=data['Cases_May_02']

# %%
# to find relation between X = 'Population' & Y = 'Cases_Feb_29'
X = dataframe.values
Y = dataframe1.values

# %%
import pandas
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

# %%
X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)

# %%
X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)
# Out:
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %% [markdown]
# Prediction:

# %%
# score on training set
decision_tree_train_score1 = dt.score(X_train,Y_train)

#prediction
print('Decision Tree: \n')
Y_pred = dt.predict(X_test)

# score on testing set
decision_tree_test_score1 = dt.score(X_test,Y_test)

'''# calculating errors:
# Mean Absolute Error: average diff bet original values & predicted values
decision_tree_mae = metrics.mean_absolute_error(Y_test, Y_pred)

# Mean Square Error: average of squares of diff bet original & predicted values
decision_tree_mse = metrics.mean_squared_error(Y_test, Y_pred)

print(decision_tree_test_score, decision_tree_mae, decision_tree_mse)'''
# Out:
# Decision Tree:
# '# calculating errors:\n# Mean Absolute Error: average diff bet original values & predicted values\ndecision_tree_mae = metrics.mean_absolute_error(Y_test, Y_pred)\n\n# Mean Square Error: average of squares of diff bet original & predicted values\ndecision_tree_mse = metrics.mean_squared_error(Y_test, Y_pred)\n\nprint(decision_tree_test_score, decision_tree_mae, decision_tree_mse)'

# %%
# to find relation between X = 'Population' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
decision_tree_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
decision_tree_test_score2 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Population' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
decision_tree_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
decision_tree_test_score3 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Population' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
decision_tree_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
decision_tree_test_score4 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Population' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
decision_tree_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
decision_tree_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Asian_Race' & Y = 'Cases_Feb_29'
dataframe=data['Asian_Race']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_asian_race_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_asian_race_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Asian_Race' & Y = 'Cases_Mar_17'
dataframe=data['Asian_Race']
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_asian_race_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_asian_race_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Asian_Race' & Y = 'Cases_Mar_31'
dataframe=data['Asian_Race']
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_asian_race_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_asian_race_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Asian_Race' & Y = 'Cases_Apr_19'
dataframe=data['Asian_Race']
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_asian_race_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_asian_race_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Asian_Race' & Y = 'Cases_May_02'
dataframe=data['Asian_Race']
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_asian_race_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_asian_race_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'White_Race' & Y = 'Cases_Feb_29'
dataframe=data['White_Race']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_white_race_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_white_race_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'White_Race' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_white_race_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_white_race_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'White_Race' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_white_race_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_white_race_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'White_Race' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_white_race_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_white_race_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'White_Race' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_white_race_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_white_race_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_Feb_29'
dataframe=data['Black_Or_African_Race']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Black_Or_African_Race_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Black_Or_African_Race_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Black_Or_African_Race_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Black_Or_African_Race_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Black_Or_African_Race_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Black_Or_African_Race_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Black_Or_African_Race_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Black_Or_African_Race_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Black_Or_African_Race' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Black_Or_African_Race_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Black_Or_African_Race_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Employed_People' & Y = 'Cases_Feb_29'
dataframe=data['Employed_People']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Employed_People_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Employed_People_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Employed_People' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Employed_People_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Employed_People_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Employed_People' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Employed_People_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Employed_People_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Employed_People' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Employed_People_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Employed_People_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Employed_People' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Employed_People_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Employed_People_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Asthma' & Y = 'Cases_Feb_29'
dataframe=data['Asthma']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Asthma_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Asthma_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Asthma' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Asthma_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Asthma_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Asthma' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Asthma_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Asthma_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Asthma' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Asthma_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Asthma_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Asthma' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Asthma_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Asthma_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Diabetes' & Y = 'Cases_Feb_29'
dataframe=data['Diabetes']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Diabetes_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Diabetes_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Diabetes' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Diabetes_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Diabetes_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Diabetes' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Diabetes_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Diabetes_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Diabetes' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Diabetes_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Diabetes_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Diabetes' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Diabetes_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Diabetes_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_Feb_29'
dataframe=data['Six_Plus_Teeth_Extractions']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Six_Plus_Teeth_Extractions_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Six_Plus_Teeth_Extractions_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Six_Plus_Teeth_Extractions_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Six_Plus_Teeth_Extractions_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Six_Plus_Teeth_Extractions_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Six_Plus_Teeth_Extractions_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Six_Plus_Teeth_Extractions_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Six_Plus_Teeth_Extractions_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Six_Plus_Teeth_Extractions' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Six_Plus_Teeth_Extractions_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Six_Plus_Teeth_Extractions_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_Feb_29'
dataframe=data['High_Blood_Pressure']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Blood_Pressure_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Blood_Pressure_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Blood_Pressure_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Blood_Pressure_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Blood_Pressure_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Blood_Pressure_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Blood_Pressure_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Blood_Pressure_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'High_Blood_Pressure' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Blood_Pressure_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Blood_Pressure_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_Feb_29'
dataframe=data['Multiple_Chronic_Conditions_Seniors']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Multiple_Chronic_Conditions_Seniors_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Multiple_Chronic_Conditions_Seniors_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Multiple_Chronic_Conditions_Seniors_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Multiple_Chronic_Conditions_Seniors_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Multiple_Chronic_Conditions_Seniors_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Multiple_Chronic_Conditions_Seniors_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Multiple_Chronic_Conditions_Seniors_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Multiple_Chronic_Conditions_Seniors_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'Multiple_Chronic_Conditions_Seniors' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_Multiple_Chronic_Conditions_Seniors_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_Multiple_Chronic_Conditions_Seniors_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
# to find relation between X = 'High_Cholesterol' & Y = 'Cases_Feb_29'
dataframe=data['High_Cholesterol']
X = dataframe.values
Y = dataframe1.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Cholesterol_train_score1 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Cholesterol_test_score1 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'High_Cholesterol' & Y = 'Cases_Mar_17'
X = dataframe.values
Y = dataframe2.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Cholesterol_train_score2 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Cholesterol_test_score2 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'High_Cholesterol' & Y = 'Cases_Mar_31'
X = dataframe.values
Y = dataframe3.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Cholesterol_train_score3 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Cholesterol_test_score3 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'High_Cholesterol' & Y = 'Cases_Apr_19'
X = dataframe.values
Y = dataframe4.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Cholesterol_train_score4 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Cholesterol_test_score4 = dt.score(X_test,Y_test)

#-------------------------------------------------------------------------------------------------------------------

# to find relation between X = 'High_Cholesterol' & Y = 'Cases_May_02'
X = dataframe.values
Y = dataframe5.values

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

X_train = X_train.reshape(X_train.shape[0],1)
Y_train = Y_train.reshape(Y_train.shape[0],1)
print("X shape:", X_train.shape)
print("Y shape:", Y_train.shape)

X_test = X_test.reshape(X_test.shape[0],1)
Y_test = Y_test.reshape(Y_test.shape[0],1)
print("X shape:", X_test.shape)
print("Y shape:", Y_test.shape)

#decision tree
dt = DecisionTreeRegressor()
dt.fit(X_train,Y_train)

# score on training set
dt_High_Cholesterol_train_score5 = dt.score(X_train,Y_train)

#prediction
Y_pred = dt.predict(X_test)

# score on testing set
dt_High_Cholesterol_test_score5 = dt.score(X_test,Y_test)
# Out:
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)
# X shape: (35, 1)
# Y shape: (35, 1)
# X shape: (16, 1)
# Y shape: (16, 1)

# %%
decision_tree_compare = pd.DataFrame( 
    {  'Dataset' : ['Cases_Feb_29', 'Cases_Mar_17', 'Cases_Mar_31', 'Cases_Apr_19', 'Cases_May_02'], 
       'Cases predicted with Population' : [decision_tree_test_score1, decision_tree_test_score2, decision_tree_test_score3, decision_tree_test_score4, decision_tree_test_score5],
       'Cases predicted with Asian Race' : [dt_asian_race_test_score1, dt_asian_race_test_score2, dt_asian_race_test_score3, dt_asian_race_test_score4, dt_asian_race_test_score5],
       'Cases predicted with White Race' : [dt_white_race_test_score1, dt_white_race_test_score2, dt_white_race_test_score3, dt_white_race_test_score4, dt_white_race_test_score5],
       'Cases predicted with Black or African Race' : [dt_Black_Or_African_Race_test_score1, dt_Black_Or_African_Race_test_score2, dt_Black_Or_African_Race_test_score3, dt_Black_Or_African_Race_test_score4, dt_Black_Or_African_Race_test_score5],
       'Cases predicted with Employed People' : [dt_Employed_People_test_score1, dt_Employed_People_test_score2, dt_Employed_People_test_score3, dt_Employed_People_test_score4, dt_Employed_People_test_score5],
       'Cases predicted with Asthma' : [dt_Asthma_test_score1, dt_Asthma_test_score2, dt_Asthma_test_score3, dt_Asthma_test_score4, dt_Asthma_test_score5],
       'Cases predicted with Diabetes' : [dt_Diabetes_test_score1, dt_Diabetes_test_score2, dt_Diabetes_test_score3, dt_Diabetes_test_score4, dt_Diabetes_test_score5],
       'Cases predicted with Six Plus Teeth Extractions' : [dt_Six_Plus_Teeth_Extractions_test_score1, dt_Six_Plus_Teeth_Extractions_test_score2, dt_Six_Plus_Teeth_Extractions_test_score3, dt_Six_Plus_Teeth_Extractions_test_score4, dt_Six_Plus_Teeth_Extractions_test_score5],
       'Cases predicted with High Blood Pressure' : [dt_High_Blood_Pressure_test_score1, dt_High_Blood_Pressure_test_score2, dt_High_Blood_Pressure_test_score3, dt_High_Blood_Pressure_test_score4, dt_High_Blood_Pressure_test_score5],
       'Cases predicted with Multiple_Chronic_Conditions_Seniors' : [dt_Multiple_Chronic_Conditions_Seniors_test_score1, dt_Multiple_Chronic_Conditions_Seniors_test_score2, dt_Multiple_Chronic_Conditions_Seniors_test_score3, dt_Multiple_Chronic_Conditions_Seniors_test_score4, dt_Multiple_Chronic_Conditions_Seniors_test_score5],
       'Cases predicted with High_Cholesterol' : [dt_High_Cholesterol_test_score1, dt_High_Cholesterol_test_score2, dt_High_Cholesterol_test_score3, dt_High_Cholesterol_test_score4, dt_High_Cholesterol_test_score5]
    }) 
print('Decision Tree Regressor Scores:\n')
print('Cases were predicted based on the following attributes:\n')
print(decision_tree_compare)
decision_tree_compare
# Out:
# Decision Tree Regressor Scores:
#
# Cases were predicted based on the following attributes:
#
#         Dataset  Cases predicted with Population  \
# 0  Cases_Feb_29                        -0.205205
# 1  Cases_Mar_17                        -0.865269
# 2  Cases_Mar_31                        -0.200014
# 3  Cases_Apr_19                        -0.114722
# 4  Cases_May_02                        -0.095870
#
#    Cases predicted with Asian Race  Cases predicted with White Race  \
# 0                        -0.213213                        -1.686687
# 1                       -21.145633                       -18.169619
# 2                       -16.822909                         0.168094
# 3                        -7.705939                        -0.054967
# 4                        -5.698551                        -0.193464
#
#    Cases predicted with Black or African Race  \
# 0                                   -0.581582
# 1                                  -10.632538
# ...

# %%
decision_tree_compare.to_csv(r'C:\Users\Maverick\Desktop\Machine Learning\Project\decision_tree_regressor_scores.csv')
