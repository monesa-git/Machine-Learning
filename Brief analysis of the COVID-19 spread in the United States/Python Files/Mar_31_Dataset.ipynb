# %%
# Load libraries
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# read data into a DataFrame
data = pd.read_csv('C:/Users/Maverick/Desktop/Machine Learning/Project/Datasetu.csv', index_col=0)
data.head()
# Out:
#            State  Cases_Feb_29  Cases_Mar_17  Cases_Mar_31  Cases_Apr_19  \
# rank
# 24       Alabama             0            39           999          4837
# 49        Alaska             0             6           133           319
# 14       Arizona             1            20          1298          4929
# 33      Arkansas             0            22           564          1777
# 1     California            28           732          8582         30852
#
#       Population   Density    White_Race  Black_Or_African_Race    Other_Race  \
# rank
# 24       4908621   96.9221  3.347189e+06           1.304711e+06  7.068414e+04
# 49        734002    1.2863  4.759269e+05           2.400187e+04  1.093663e+04
# 14       7378494   64.9550  5.697673e+06           3.239159e+05  5.009997e+05
# 33       3038999   58.4030  2.340029e+06           4.683097e+05  8.022957e+04
# 1       39937489  256.3727  2.400243e+07           2.312381e+06  5.523355e+06
#
# ...

# %% [markdown]
# ### Single Linear Regression
# To find the attributes that have relation to the number of cases.
# The coefficient and pvalue is found out.

# %%
# this is the standard import if you're using "formula notation" (similar to R)
import statsmodels.formula.api as smf

# create a fitted model in one line
Pop_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Population', data=data).fit()

# print the coefficients
print(Pop_Cases_lm.params)
print(Pop_Cases_lm.pvalues)
# Out:
# Intercept    -15.479559
# Population     0.000569
# dtype: float64
# Intercept     0.993436
# Population    0.004398
# dtype: float64

# %%
# create a fitted model in one line
Density_Cases_lm = smf.ols(formula='Cases_Per_Sq_Mile_Mar_31 ~ Density', data=data).fit()

# print the coefficients
print(Density_Cases_lm.params)
print(Density_Cases_lm.pvalues)
# Out:
# Intercept   -37.225932
# Density       7.225667
# dtype: float64
# Intercept    9.782356e-01
# Density      6.323462e-12
# dtype: float64

# %%
# create a fitted model in one line
White_Race_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ White_Race', data=data).fit()

# print the coefficients
print(White_Race_Cases_lm.params)
print(White_Race_Cases_lm.pvalues)
# Out:
# Intercept    -35.315298
# White_Race     0.000786
# dtype: float64
# Intercept     0.985753
# White_Race    0.008700
# dtype: float64

# %%
# create a fitted model in one line
Black_Or_African_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Black_Or_African_Race', data=data).fit()

# print the coefficients
print(Black_Or_African_Cases_lm.params)
print(Black_Or_African_Cases_lm.pvalues)
# Out:
# Intercept               -209.656900
# Black_Or_African_Race      0.004728
# dtype: float64
# Intercept                0.907128
# Black_Or_African_Race    0.001350
# dtype: float64

# %%
# create a fitted model in one line
Other_Race_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Other_Race', data=data).fit()

# print the coefficients
print(Other_Race_Cases_lm.params)
print(Other_Race_Cases_lm.pvalues)
# Out:
# Intercept     2215.953568
# Other_Race       0.004613
# dtype: float64
# Intercept     0.155437
# Other_Race    0.011718
# dtype: float64

# %%
# create a fitted model in one line
Asian_Race_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Asian_Race', data=data).fit()

# print the coefficients
print(Asian_Race_Cases_lm.params)
print(Asian_Race_Cases_lm.pvalues)
# Out:
# Intercept     2128.884066
# Asian_Race       0.004399
# dtype: float64
# Intercept     0.179078
# Asian_Race    0.014688
# dtype: float64

# %%
# create a fitted model in one line
Two_Or_More_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Two_Or_More_Race', data=data).fit()

# print the coefficients
print(Two_Or_More_Cases_lm.params)
print(Two_Or_More_Cases_lm.pvalues)
# Out:
# Intercept           1267.865357
# Two_Or_More_Race       0.011511
# dtype: float64
# Intercept           0.481452
# Two_Or_More_Race    0.025188
# dtype: float64

# %%
# create a fitted model in one line
Native_American_Race_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Native_American_Race', data=data).fit()

# print the coefficients
print(Native_American_Race_Cases_lm.params)
print(Native_American_Race_Cases_lm.pvalues)
# Out:
# Intercept               3111.988054
# Native_American_Race       0.010412
# dtype: float64
# Intercept               0.104733
# Native_American_Race    0.610465
# dtype: float64

# %%
# create a fitted model in one line
Native_Hawaiian_Race_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Native_Hawaiian_Race', data=data).fit()

# print the coefficients
print(Native_Hawaiian_Race_Cases_lm.params)
print(Native_Hawaiian_Race_Cases_lm.pvalues)
# Out:
# Intercept               3519.536890
# Native_Hawaiian_Race       0.013706
# dtype: float64
# Intercept               0.037228
# Native_Hawaiian_Race    0.794380
# dtype: float64

# %%
# create a fitted model in one line
Employed_People_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Employed_People', data=data).fit()

# print the coefficients
print(Employed_People_Cases_lm.params)
print(Employed_People_Cases_lm.pvalues)
# Out:
# Intercept         -127.551990
# Employed_People      0.001236
# dtype: float64
# Intercept          0.946316
# Employed_People    0.003973
# dtype: float64

# %%
# create a fitted model in one line
UnEmployed_People_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ UnEmployed_People', data=data).fit()

# print the coefficients
print(UnEmployed_People_Cases_lm.params)
print(UnEmployed_People_Cases_lm.pvalues)
# Out:
# Intercept            91.51655
# UnEmployed_People     0.00105
# dtype: float64
# Intercept            0.960965
# UnEmployed_People    0.004869
# dtype: float64

# %%
# create a fitted model in one line
Mean_Temp_Mar_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Mean_Temp_Mar', data=data).fit()

# print the coefficients
print(Mean_Temp_Mar_Cases_lm.params)
print(Mean_Temp_Mar_Cases_lm.pvalues)
# Out:
# Intercept        3436.093067
# Mean_Temp_Mar       5.429496
# dtype: float64
# Intercept        0.624462
# Mean_Temp_Mar    0.971649
# dtype: float64

# %%
# create a fitted model in one line
Median_Age_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Median_Age', data=data).fit()

# print the coefficients
print(Median_Age_Cases_lm.params)
print(Median_Age_Cases_lm.pvalues)
# Out:
# Intercept    -5335.682180
# Median_Age     235.761649
# dtype: float64
# Intercept     0.826333
# Median_Age    0.710440
# dtype: float64

# %%
# create a fitted model in one line
Air_Pollution_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Air_Pollution', data=data).fit()

# print the coefficients
print(Air_Pollution_Cases_lm.params)
print(Air_Pollution_Cases_lm.pvalues)
# Out:
# Intercept        13565.332888
# Air_Pollution    -1304.847250
# dtype: float64
# Intercept        0.108765
# Air_Pollution    0.231878
# dtype: float64

# %%
# create a fitted model in one line
Asthma_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Asthma', data=data).fit()

# print the coefficients
print(Asthma_Cases_lm.params)
print(Asthma_Cases_lm.pvalues)

# create a fitted model in one line
Diabetes_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Diabetes', data=data).fit()

# print the coefficients
print(Diabetes_Cases_lm.params)
print(Diabetes_Cases_lm.pvalues)

# create a fitted model in one line
Teeth_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Six_Plus_Teeth_Extractions', data=data).fit()

# print the coefficients
print(Teeth_Cases_lm.params)
print(Teeth_Cases_lm.pvalues)

# create a fitted model in one line
hbp_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ High_Blood_Pressure', data=data).fit()

# print the coefficients
print(hbp_Cases_lm.params)
print(hbp_Cases_lm.pvalues)

# create a fitted model in one line
multiple_chronic_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Multiple_Chronic_Conditions_Seniors', data=data).fit()

# print the coefficients
print(multiple_chronic_Cases_lm.params)
print(multiple_chronic_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Disease_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Heart_Disease', data=data).fit()

# print the coefficients
print(Heart_Disease_Cases_lm.params)
print(Heart_Disease_Cases_lm.pvalues)

# create a fitted model in one line
Heart_Attack_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Heart_Attack', data=data).fit()

# print the coefficients
print(Heart_Attack_Cases_lm.params)
print(Heart_Attack_Cases_lm.pvalues)

# create a fitted model in one line
Stroke_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Stroke', data=data).fit()

# print the coefficients
print(Stroke_Cases_lm.params)
print(Stroke_Cases_lm.pvalues)

# create a fitted model in one line
High_Cholesterol_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ High_Cholesterol', data=data).fit()

# print the coefficients
print(High_Cholesterol_Cases_lm.params)
print(High_Cholesterol_Cases_lm.pvalues)
# Out:
# Intercept   -88.588862
# Asthma        0.007262
# dtype: float64
# Intercept    0.962698
# Asthma       0.004266
# dtype: float64
# Intercept    200.655116
# Diabetes       0.004708
# dtype: float64
# Intercept    0.915615
# Diabetes     0.007213
# dtype: float64
# Intercept                    -754.620656
# Six_Plus_Teeth_Extractions      0.003752
# dtype: float64
# Intercept                     0.705314
# Six_Plus_Teeth_Extractions    0.002861
# dtype: float64
# Intercept             -9.572732
# High_Blood_Pressure    0.001752
# dtype: float64
# Intercept              0.996071
# High_Blood_Pressure    0.007209
# dtype: float64
# Intercept                             -193.705053
# Multiple_Chronic_Conditions_Seniors      0.001585
# dtype: float64
# Intercept                              0.915408
# Multiple_Chronic_Conditions_Seniors    0.001834
# dtype: float64
# Intercept       -164.007511
# Heart_Disease      0.013755
# dtype: float64
# Intercept        0.934555
# ...

# %% [markdown]
# ### Multiple Linear Regression

# %%
# create a fitted model with best features identified based on their pvalues
mul_pvalues_best_attributes_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Population + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()

# print the coefficients
mul_pvalues_best_attributes_Cases_lm.params
mul_pvalues_best_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Mar_31   R-squared:                       0.784
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     8.493
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           1.09e-07
# Time:                        00:36:28   Log-Likelihood:                -506.37
# No. Observations:                  51   AIC:                             1045.
# Df Residuals:                      35   BIC:                             1076.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with all features
mul_All_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Native_American_Race + Native_Hawaiian_Race + Employed_People + Mean_Temp_Feb + Median_Age + Air_Pollution + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + Stroke + High_Cholesterol', data=data).fit()

# print the coefficients
mul_All_Cases_lm.params
mul_All_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Mar_31   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     5.901
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           8.74e-06
# Time:                        00:35:27   Log-Likelihood:                -503.11
# No. Observations:                  51   AIC:                             1050.
# Df Residuals:                      29   BIC:                             1093.
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with features identified to have best rsquared values - based on mean
mul_mean_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Population + White_Race + Black_Or_African_Race + Other_Race + Asian_Race + Two_Or_More_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Multiple_Chronic_Conditions_Seniors + Heart_Disease + Heart_Attack + High_Cholesterol', data=data).fit()

# print the coefficients
mul_mean_best_rsquared_attributes_Cases_lm.params
mul_mean_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Mar_31   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.636
# Method:                 Least Squares   F-statistic:                     6.813
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           1.53e-06
# Time:                        00:38:10   Log-Likelihood:                -510.67
# No. Observations:                  51   AIC:                             1053.
# Df Residuals:                      35   BIC:                             1084.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model with features identified to have best rsquared values - based on median
mul_median_best_rsquared_attributes_Cases_lm = smf.ols(formula='Cases_Mar_31 ~ Population + White_Race + Black_Or_African_Race + Two_Or_More_Race + Employed_People + Asthma + Diabetes + Six_Plus_Teeth_Extractions + High_Blood_Pressure + Heart_Disease + High_Cholesterol', data=data).fit()

# print the coefficients
mul_median_best_rsquared_attributes_Cases_lm.params
mul_median_best_rsquared_attributes_Cases_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Cases_Mar_31   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.517
# Method:                 Least Squares   F-statistic:                     5.861
# Date:                Mon, 20 Apr 2020   Prob (F-statistic):           1.63e-05
# Time:                        00:39:11   Log-Likelihood:                -520.62
# No. Observations:                  51   AIC:                             1065.
# Df Residuals:                      39   BIC:                             1088.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...
